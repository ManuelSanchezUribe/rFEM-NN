# %% [markdown]
# ## Libraries

# %%
#########################################################################################################
# An r-adaptive finite element method using neural networks for parametric self-adjoint elliptic problems
# Author: Danilo Aballay, Federico Fuentes, Vicente Iligaray, Ángel J. Omella,
#         David Pardo, Manuel A. Sánchez, Ignacio Tapia, Carlos Uriarte
#########################################################################################################

import jax.numpy as jnp
from jax import random, grad, jit
import jax
import jax.nn as nn
import numpy as np
from jax.example_libraries import optimizers
import matplotlib.pyplot as plt
import pandas as pd
import os
import sys
from fem_system import solve_and_loss, solve, solve_and_loss_scipy

os.environ["TF_ENABLE_ONEDNN_OPTS"] = "1"
os.environ["KERAS_BACKEND"] = "jax"
import keras

# Set the random seed
keras.utils.set_random_seed(1234)

dtype='float64' # double precision set to default in the SCR functions
jax.config.update("jax_enable_x64", True)
keras.backend.set_floatx(dtype)


sys.path.append(os.path.abspath('..'))
key = jax.random.PRNGKey(0)

# %% [markdown]
# ### Import dataset

# %%
dataset       = np.array(pd.read_csv('Dataset/dataset.csv').values)
train_indices = np.array(pd.read_csv('Dataset/train_indices.csv').train_indices)
test_indices  = np.array(pd.read_csv('Dataset/test_indices.csv').test_indices)

train_data   = dataset[train_indices]
test_data    = dataset[test_indices]
subset_test  = np.array(pd.read_csv('Dataset/test_subset.csv').values)

# %% [markdown]
# ### Ritz with uniform grid

# %%
def Exact_Ritz(alpha, s):
    eval_r = lambda x: 0.5* alpha * ((alpha * (-s + x))/(1 + alpha**2 * (s - x)**2) - np.arctan(alpha* (s - x)))
    return - 0.5 * (eval_r(1)- eval_r(0))

# %%
# Define the number of nodes
n_nodes       = 16
uniform_grid  = jnp.linspace(0, 1, n_nodes + 1)

# %%
# Compute the ritz value with uniform mesh for training set
ritz_dict_train = {str(a): solve_and_loss(uniform_grid, a) for a in np.concatenate((train_data, subset_test))}

# Compute the ritz value with uniform mesh for test set
ritz_dict_test = {str(a): solve_and_loss(uniform_grid, a) for a in test_data}

# %% [markdown]
# ### Neural Network

# %%
# Neural Network parameters

def init_params(layers, key):
    Ws = []
    bs = []
    for i in range(len(layers) - 1):
        std_lecun = jnp.sqrt(1 / layers[i])
        key, subkey = random.split(key)
        Ws.append(random.normal(subkey, (layers[i], layers[i + 1])) * std_lecun)
        bs.append(jnp.zeros(layers[i + 1]))
    return [Ws, bs]

@jit
def forward_pass(A_t, params):
    Ws, bs = params
    H = A_t
    for i in range(len(Ws) - 1):
        H = jnp.matmul(H, Ws[i]) + bs[i]
        H = jnp.tanh(H)
    theta = nn.softmax(jnp.matmul(H, Ws[-1]) + bs[-1], axis = -1)
    nodes = jnp.cumsum(theta, axis = -1)
    return jnp.insert(nodes, 0, 0, axis = -1)

def loss(params, alphas):
    losses = solve_and_loss_scipy(forward_pass(alphas, params), alphas.reshape(-1, 2))
    return jnp.array([losses[i] / abs(ritz_dict_train[str(alpha)]) for i, alpha in enumerate(alphas)]).mean()

def loss_test(params, alphas, J_u):
    # Export history error
    J_u_theta = solve_and_loss_scipy(forward_pass(alphas, params), alphas.reshape(-1, 2))
    return jnp.mean(jnp.sqrt(np.abs((J_u - J_u_theta)/J_u)))

def FEM_sol(params, alpha):
    nodes = forward_pass(alpha, params)
    return solve(nodes, jnp.squeeze(alpha))

def train(loss_fn, opt_state, alphas, test_subset, n_epochs=10, n_iter_per_epoch=1000, batch_size=1, lr=1e-2):
    train_loss = []
    test_loss  = []
    J_u        = jnp.array([Exact_Ritz(subset_test[i,0], subset_test[i,1]) for i in range(len(subset_test))])
    key = random.PRNGKey(100)
    n_alphas = alphas.shape[0]
    opt_init, opt_update, get_params = optimizers.adam(lr)
    params   = get_params(opt_state)
    
    for epoch in range(n_epochs):
        key, subkey = random.split(key)
        idx = random.choice(subkey, n_alphas, (batch_size,), replace=False)
        sigma_batch = alphas[idx]

        for it in range(n_iter_per_epoch):
            params    = get_params(opt_state)
            grads     = grad(loss_fn)(params, sigma_batch)
            opt_state = opt_update(0, grads, opt_state)
        
        # Update learning rate strategy
        if epoch == 2800:
            lr  = 1e-3
            opt_init, opt_update, get_params = optimizers.adam(lr)
            opt_state = opt_init(params)
        
        params = get_params(opt_state)
        loss_val = loss_fn(params, sigma_batch)
        train_loss.append(loss_val)
        test_loss.append(loss_test(params, test_subset, J_u))

        if epoch % 100 == 0:
            print(f"Epoch {epoch}, Training loss: {loss_val:.4e}, Test loss: {test_loss[-1]:.4e}, Learning rate: {lr:.4e}")

    return get_params(opt_state), opt_state, train_loss, test_loss

# %% [markdown]
# ### Training

# %%
# Network parameters and training configuration
iter       = 1  # Number of iterations per epoch
epochs     = 35000
lr         = 1e-2
batch_size = 10

# Define the neural network architecture
layers = [2, 10, 10, n_nodes]
key    = random.PRNGKey(42)

# Initialize the optimizer and parameters
opt_init, opt_update, get_params = optimizers.adam(lr)
params    = init_params(layers, key)
opt_state = opt_init(params)

# Train the model
trained_param, opt_state_save, trained_error, test_loss = train(loss, opt_state, jnp.array(train_data), jnp.array(subset_test), epochs, iter, batch_size, lr)
# Out:
# Epoch 0, Training loss: -9.2746e-01, Test loss: 4.6924e-01, Learning rate: 1.0000e-02
# Epoch 100, Training loss: -1.0284e+00, Test loss: 3.2278e-01, Learning rate: 1.0000e-02
# Epoch 200, Training loss: -1.0508e+00, Test loss: 3.3649e-01, Learning rate: 1.0000e-02
# Epoch 300, Training loss: -1.0820e+00, Test loss: 3.8617e-01, Learning rate: 1.0000e-02
# Epoch 400, Training loss: -1.0849e+00, Test loss: 3.4991e-01, Learning rate: 1.0000e-02
# Epoch 500, Training loss: -1.1090e+00, Test loss: 3.1999e-01, Learning rate: 1.0000e-02
# Epoch 600, Training loss: -1.1521e+00, Test loss: 2.9691e-01, Learning rate: 1.0000e-02
# Epoch 700, Training loss: -1.1092e+00, Test loss: 2.9260e-01, Learning rate: 1.0000e-02
# Epoch 800, Training loss: -1.0668e+00, Test loss: 2.9529e-01, Learning rate: 1.0000e-02
# Epoch 900, Training loss: -1.0303e+00, Test loss: 3.1402e-01, Learning rate: 1.0000e-02
# Epoch 1000, Training loss: -1.1087e+00, Test loss: 3.6506e-01, Learning rate: 1.0000e-02
# Epoch 1100, Training loss: -1.0063e+00, Test loss: 3.7914e-01, Learning rate: 1.0000e-02
# Epoch 1200, Training loss: -1.1564e+00, Test loss: 3.4962e-01, Learning rate: 1.0000e-02
# Epoch 1300, Training loss: -1.0886e+00, Test loss: 3.6528e-01, Learning rate: 1.0000e-02
# Epoch 1400, Training loss: -1.1387e+00, Test loss: 3.2393e-01, Learning rate: 1.0000e-02
# Epoch 1500, Training loss: -1.0705e+00, Test loss: 3.0631e-01, Learning rate: 1.0000e-02
# Epoch 1600, Training loss: -1.1070e+00, Test loss: 3.1424e-01, Learning rate: 1.0000e-02
# Epoch 1700, Training loss: -1.0389e+00, Test loss: 3.7571e-01, Learning rate: 1.0000e-02
# Epoch 1800, Training loss: -1.0961e+00, Test loss: 3.0677e-01, Learning rate: 1.0000e-02
# Epoch 1900, Training loss: -1.0594e+00, Test loss: 3.0807e-01, Learning rate: 1.0000e-02
# Epoch 2000, Training loss: -1.0986e+00, Test loss: 2.9383e-01, Learning rate: 1.0000e-02
# Epoch 2100, Training loss: -1.0518e+00, Test loss: 3.6746e-01, Learning rate: 1.0000e-02
# Epoch 2200, Training loss: -1.1050e+00, Test loss: 3.7192e-01, Learning rate: 1.0000e-02
# Epoch 2300, Training loss: -1.0619e+00, Test loss: 3.4048e-01, Learning rate: 1.0000e-02
# Epoch 2400, Training loss: -1.0588e+00, Test loss: 3.2282e-01, Learning rate: 1.0000e-02
# Epoch 2500, Training loss: -1.0178e+00, Test loss: 3.5215e-01, Learning rate: 1.0000e-02
# Epoch 2600, Training loss: -1.0382e+00, Test loss: 3.2219e-01, Learning rate: 1.0000e-02
# Epoch 2700, Training loss: -1.1068e+00, Test loss: 3.5087e-01, Learning rate: 1.0000e-02
# Epoch 2800, Training loss: -1.0928e+00, Test loss: 3.0207e-01, Learning rate: 1.0000e-03
# Epoch 2900, Training loss: -1.0605e+00, Test loss: 3.2405e-01, Learning rate: 1.0000e-03
# Epoch 3000, Training loss: -1.0488e+00, Test loss: 3.0602e-01, Learning rate: 1.0000e-03
# Epoch 3100, Training loss: -1.0555e+00, Test loss: 2.8952e-01, Learning rate: 1.0000e-03
# Epoch 3200, Training loss: -1.0186e+00, Test loss: 3.1010e-01, Learning rate: 1.0000e-03
# Epoch 3300, Training loss: -1.1008e+00, Test loss: 3.2845e-01, Learning rate: 1.0000e-03
# Epoch 3400, Training loss: -1.0708e+00, Test loss: 3.4119e-01, Learning rate: 1.0000e-03
# Epoch 3500, Training loss: -1.0714e+00, Test loss: 2.9854e-01, Learning rate: 1.0000e-03
# Epoch 3600, Training loss: -1.0266e+00, Test loss: 3.4037e-01, Learning rate: 1.0000e-03
# Epoch 3700, Training loss: -1.0614e+00, Test loss: 3.0186e-01, Learning rate: 1.0000e-03
# Epoch 3800, Training loss: -1.0593e+00, Test loss: 3.0565e-01, Learning rate: 1.0000e-03
# Epoch 3900, Training loss: -1.1361e+00, Test loss: 3.0992e-01, Learning rate: 1.0000e-03
# Epoch 4000, Training loss: -1.0175e+00, Test loss: 2.7190e-01, Learning rate: 1.0000e-03
# Epoch 4100, Training loss: -1.1052e+00, Test loss: 2.8035e-01, Learning rate: 1.0000e-03
# Epoch 4200, Training loss: -1.1143e+00, Test loss: 2.5231e-01, Learning rate: 1.0000e-03
# Epoch 4300, Training loss: -1.1302e+00, Test loss: 3.7631e-01, Learning rate: 1.0000e-03
# Epoch 4400, Training loss: -1.1891e+00, Test loss: 3.2935e-01, Learning rate: 1.0000e-03
# Epoch 4500, Training loss: -1.0686e+00, Test loss: 2.9712e-01, Learning rate: 1.0000e-03
# Epoch 4600, Training loss: -1.0628e+00, Test loss: 2.6631e-01, Learning rate: 1.0000e-03
# Epoch 4700, Training loss: -1.1080e+00, Test loss: 2.6281e-01, Learning rate: 1.0000e-03
# Epoch 4800, Training loss: -1.0793e+00, Test loss: 2.9789e-01, Learning rate: 1.0000e-03
# Epoch 4900, Training loss: -1.0968e+00, Test loss: 2.5098e-01, Learning rate: 1.0000e-03
# Epoch 5000, Training loss: -1.0892e+00, Test loss: 2.7465e-01, Learning rate: 1.0000e-03
# Epoch 5100, Training loss: -1.0613e+00, Test loss: 2.4850e-01, Learning rate: 1.0000e-03
# Epoch 5200, Training loss: -1.0968e+00, Test loss: 2.9137e-01, Learning rate: 1.0000e-03
# Epoch 5300, Training loss: -1.1553e+00, Test loss: 2.5404e-01, Learning rate: 1.0000e-03
# Epoch 5400, Training loss: -1.1011e+00, Test loss: 2.4784e-01, Learning rate: 1.0000e-03
# Epoch 5500, Training loss: -1.1360e+00, Test loss: 2.4935e-01, Learning rate: 1.0000e-03
# Epoch 5600, Training loss: -1.1773e+00, Test loss: 2.6409e-01, Learning rate: 1.0000e-03
# Epoch 5700, Training loss: -1.0994e+00, Test loss: 2.3946e-01, Learning rate: 1.0000e-03
# Epoch 5800, Training loss: -1.0881e+00, Test loss: 2.3614e-01, Learning rate: 1.0000e-03
# Epoch 5900, Training loss: -1.2083e+00, Test loss: 2.1249e-01, Learning rate: 1.0000e-03
# Epoch 6000, Training loss: -1.1105e+00, Test loss: 2.1415e-01, Learning rate: 1.0000e-03
# Epoch 6100, Training loss: -1.1702e+00, Test loss: 2.0335e-01, Learning rate: 1.0000e-03
# Epoch 6200, Training loss: -1.1594e+00, Test loss: 2.0014e-01, Learning rate: 1.0000e-03
# Epoch 6300, Training loss: -1.1116e+00, Test loss: 2.1710e-01, Learning rate: 1.0000e-03
# Epoch 6400, Training loss: -1.2424e+00, Test loss: 1.7951e-01, Learning rate: 1.0000e-03
# Epoch 6500, Training loss: -1.2157e+00, Test loss: 1.7240e-01, Learning rate: 1.0000e-03
# Epoch 6600, Training loss: -1.1660e+00, Test loss: 1.6514e-01, Learning rate: 1.0000e-03
# Epoch 6700, Training loss: -1.1415e+00, Test loss: 1.5839e-01, Learning rate: 1.0000e-03
# Epoch 6800, Training loss: -1.2558e+00, Test loss: 1.5135e-01, Learning rate: 1.0000e-03
# Epoch 6900, Training loss: -1.1433e+00, Test loss: 1.4705e-01, Learning rate: 1.0000e-03
# Epoch 7000, Training loss: -1.1418e+00, Test loss: 1.3950e-01, Learning rate: 1.0000e-03
# Epoch 7100, Training loss: -1.0953e+00, Test loss: 1.3476e-01, Learning rate: 1.0000e-03
# Epoch 7200, Training loss: -1.1690e+00, Test loss: 1.3022e-01, Learning rate: 1.0000e-03
# Epoch 7300, Training loss: -1.1686e+00, Test loss: 1.2777e-01, Learning rate: 1.0000e-03
# Epoch 7400, Training loss: -1.1944e+00, Test loss: 1.2539e-01, Learning rate: 1.0000e-03
# Epoch 7500, Training loss: -1.1485e+00, Test loss: 1.2171e-01, Learning rate: 1.0000e-03
# Epoch 7600, Training loss: -1.2083e+00, Test loss: 1.1908e-01, Learning rate: 1.0000e-03
# Epoch 7700, Training loss: -1.2729e+00, Test loss: 1.1787e-01, Learning rate: 1.0000e-03
# Epoch 7800, Training loss: -1.2044e+00, Test loss: 1.1538e-01, Learning rate: 1.0000e-03
# Epoch 7900, Training loss: -1.1954e+00, Test loss: 1.1569e-01, Learning rate: 1.0000e-03
# Epoch 8000, Training loss: -1.2139e+00, Test loss: 1.1455e-01, Learning rate: 1.0000e-03
# Epoch 8100, Training loss: -1.1793e+00, Test loss: 1.1267e-01, Learning rate: 1.0000e-03
# Epoch 8200, Training loss: -1.2578e+00, Test loss: 1.1738e-01, Learning rate: 1.0000e-03
# Epoch 8300, Training loss: -1.1985e+00, Test loss: 1.1107e-01, Learning rate: 1.0000e-03
# Epoch 8400, Training loss: -1.1019e+00, Test loss: 1.1015e-01, Learning rate: 1.0000e-03
# Epoch 8500, Training loss: -1.2274e+00, Test loss: 1.0973e-01, Learning rate: 1.0000e-03
# Epoch 8600, Training loss: -1.1791e+00, Test loss: 1.0982e-01, Learning rate: 1.0000e-03
# Epoch 8700, Training loss: -1.1146e+00, Test loss: 1.0973e-01, Learning rate: 1.0000e-03
# Epoch 8800, Training loss: -1.2176e+00, Test loss: 1.0865e-01, Learning rate: 1.0000e-03
# Epoch 8900, Training loss: -1.2173e+00, Test loss: 1.0834e-01, Learning rate: 1.0000e-03
# Epoch 9000, Training loss: -1.2352e+00, Test loss: 1.0684e-01, Learning rate: 1.0000e-03
# Epoch 9100, Training loss: -1.1582e+00, Test loss: 1.0741e-01, Learning rate: 1.0000e-03
# Epoch 9200, Training loss: -1.1885e+00, Test loss: 1.0646e-01, Learning rate: 1.0000e-03
# Epoch 9300, Training loss: -1.2527e+00, Test loss: 1.0546e-01, Learning rate: 1.0000e-03
# Epoch 9400, Training loss: -1.1536e+00, Test loss: 1.0542e-01, Learning rate: 1.0000e-03
# Epoch 9500, Training loss: -1.1841e+00, Test loss: 1.0559e-01, Learning rate: 1.0000e-03
# Epoch 9600, Training loss: -1.1845e+00, Test loss: 1.0588e-01, Learning rate: 1.0000e-03
# Epoch 9700, Training loss: -1.1989e+00, Test loss: 1.0483e-01, Learning rate: 1.0000e-03
# Epoch 9800, Training loss: -1.2183e+00, Test loss: 1.0551e-01, Learning rate: 1.0000e-03
# Epoch 9900, Training loss: -1.2026e+00, Test loss: 1.0487e-01, Learning rate: 1.0000e-03
# Epoch 10000, Training loss: -1.1757e+00, Test loss: 1.0360e-01, Learning rate: 1.0000e-03
# Epoch 10100, Training loss: -1.2005e+00, Test loss: 1.0487e-01, Learning rate: 1.0000e-03
# Epoch 10200, Training loss: -1.1734e+00, Test loss: 1.0405e-01, Learning rate: 1.0000e-03
# Epoch 10300, Training loss: -1.1665e+00, Test loss: 1.0269e-01, Learning rate: 1.0000e-03
# Epoch 10400, Training loss: -1.2061e+00, Test loss: 1.0252e-01, Learning rate: 1.0000e-03
# Epoch 10500, Training loss: -1.1600e+00, Test loss: 1.0256e-01, Learning rate: 1.0000e-03
# Epoch 10600, Training loss: -1.0983e+00, Test loss: 1.0215e-01, Learning rate: 1.0000e-03
# Epoch 10700, Training loss: -1.1837e+00, Test loss: 1.0307e-01, Learning rate: 1.0000e-03
# Epoch 10800, Training loss: -1.1643e+00, Test loss: 1.0172e-01, Learning rate: 1.0000e-03
# Epoch 10900, Training loss: -1.1910e+00, Test loss: 1.0149e-01, Learning rate: 1.0000e-03
# Epoch 11000, Training loss: -1.1378e+00, Test loss: 1.0270e-01, Learning rate: 1.0000e-03
# Epoch 11100, Training loss: -1.1562e+00, Test loss: 1.0202e-01, Learning rate: 1.0000e-03
# Epoch 11200, Training loss: -1.1986e+00, Test loss: 1.0087e-01, Learning rate: 1.0000e-03
# Epoch 11300, Training loss: -1.1858e+00, Test loss: 1.0164e-01, Learning rate: 1.0000e-03
# Epoch 11400, Training loss: -1.1864e+00, Test loss: 1.0041e-01, Learning rate: 1.0000e-03
# Epoch 11500, Training loss: -1.2523e+00, Test loss: 1.0025e-01, Learning rate: 1.0000e-03
# Epoch 11600, Training loss: -1.2277e+00, Test loss: 1.0025e-01, Learning rate: 1.0000e-03
# Epoch 11700, Training loss: -1.1034e+00, Test loss: 1.0003e-01, Learning rate: 1.0000e-03
# Epoch 11800, Training loss: -1.2042e+00, Test loss: 1.0074e-01, Learning rate: 1.0000e-03
# Epoch 11900, Training loss: -1.2456e+00, Test loss: 9.9802e-02, Learning rate: 1.0000e-03
# Epoch 12000, Training loss: -1.1830e+00, Test loss: 9.9403e-02, Learning rate: 1.0000e-03
# Epoch 12100, Training loss: -1.2361e+00, Test loss: 1.0048e-01, Learning rate: 1.0000e-03
# Epoch 12200, Training loss: -1.2252e+00, Test loss: 1.0034e-01, Learning rate: 1.0000e-03
# Epoch 12300, Training loss: -1.2776e+00, Test loss: 9.9360e-02, Learning rate: 1.0000e-03
# Epoch 12400, Training loss: -1.1939e+00, Test loss: 9.8672e-02, Learning rate: 1.0000e-03
# Epoch 12500, Training loss: -1.2606e+00, Test loss: 9.9287e-02, Learning rate: 1.0000e-03
# Epoch 12600, Training loss: -1.2456e+00, Test loss: 9.8447e-02, Learning rate: 1.0000e-03
# Epoch 12700, Training loss: -1.1264e+00, Test loss: 9.9630e-02, Learning rate: 1.0000e-03
# Epoch 12800, Training loss: -1.1193e+00, Test loss: 9.8011e-02, Learning rate: 1.0000e-03
# Epoch 12900, Training loss: -1.1234e+00, Test loss: 9.8446e-02, Learning rate: 1.0000e-03
# Epoch 13000, Training loss: -1.1779e+00, Test loss: 9.8137e-02, Learning rate: 1.0000e-03
# Epoch 13100, Training loss: -1.1986e+00, Test loss: 9.7506e-02, Learning rate: 1.0000e-03
# Epoch 13200, Training loss: -1.2431e+00, Test loss: 9.7992e-02, Learning rate: 1.0000e-03
# Epoch 13300, Training loss: -1.2092e+00, Test loss: 9.7905e-02, Learning rate: 1.0000e-03
# Epoch 13400, Training loss: -1.1551e+00, Test loss: 9.9151e-02, Learning rate: 1.0000e-03
# Epoch 13500, Training loss: -1.1688e+00, Test loss: 1.0254e-01, Learning rate: 1.0000e-03
# Epoch 13600, Training loss: -1.2342e+00, Test loss: 9.7375e-02, Learning rate: 1.0000e-03
# Epoch 13700, Training loss: -1.1975e+00, Test loss: 9.9724e-02, Learning rate: 1.0000e-03
# Epoch 13800, Training loss: -1.1595e+00, Test loss: 1.0055e-01, Learning rate: 1.0000e-03
# Epoch 13900, Training loss: -1.2419e+00, Test loss: 9.8005e-02, Learning rate: 1.0000e-03
# Epoch 14000, Training loss: -1.1847e+00, Test loss: 9.7574e-02, Learning rate: 1.0000e-03
# Epoch 14100, Training loss: -1.1781e+00, Test loss: 9.7227e-02, Learning rate: 1.0000e-03
# Epoch 14200, Training loss: -1.1239e+00, Test loss: 9.7237e-02, Learning rate: 1.0000e-03
# Epoch 14300, Training loss: -1.1077e+00, Test loss: 9.7675e-02, Learning rate: 1.0000e-03
# Epoch 14400, Training loss: -1.1596e+00, Test loss: 9.7213e-02, Learning rate: 1.0000e-03
# Epoch 14500, Training loss: -1.1597e+00, Test loss: 9.8236e-02, Learning rate: 1.0000e-03
# Epoch 14600, Training loss: -1.2854e+00, Test loss: 9.7927e-02, Learning rate: 1.0000e-03
# Epoch 14700, Training loss: -1.2029e+00, Test loss: 9.8373e-02, Learning rate: 1.0000e-03
# Epoch 14800, Training loss: -1.1948e+00, Test loss: 9.7446e-02, Learning rate: 1.0000e-03
# Epoch 14900, Training loss: -1.1658e+00, Test loss: 9.7685e-02, Learning rate: 1.0000e-03
# Epoch 15000, Training loss: -1.1890e+00, Test loss: 9.7725e-02, Learning rate: 1.0000e-03
# Epoch 15100, Training loss: -1.1824e+00, Test loss: 9.7205e-02, Learning rate: 1.0000e-03
# Epoch 15200, Training loss: -1.1525e+00, Test loss: 9.8112e-02, Learning rate: 1.0000e-03
# Epoch 15300, Training loss: -1.2010e+00, Test loss: 9.8546e-02, Learning rate: 1.0000e-03
# Epoch 15400, Training loss: -1.1849e+00, Test loss: 9.7344e-02, Learning rate: 1.0000e-03
# Epoch 15500, Training loss: -1.2665e+00, Test loss: 9.6423e-02, Learning rate: 1.0000e-03
# Epoch 15600, Training loss: -1.2149e+00, Test loss: 9.6195e-02, Learning rate: 1.0000e-03
# Epoch 15700, Training loss: -1.2595e+00, Test loss: 9.6181e-02, Learning rate: 1.0000e-03
# Epoch 15800, Training loss: -1.2016e+00, Test loss: 9.5615e-02, Learning rate: 1.0000e-03
# Epoch 15900, Training loss: -1.1813e+00, Test loss: 9.6388e-02, Learning rate: 1.0000e-03
# Epoch 16000, Training loss: -1.2400e+00, Test loss: 9.8799e-02, Learning rate: 1.0000e-03
# Epoch 16100, Training loss: -1.1726e+00, Test loss: 9.6583e-02, Learning rate: 1.0000e-03
# Epoch 16200, Training loss: -1.2273e+00, Test loss: 9.7023e-02, Learning rate: 1.0000e-03
# Epoch 16300, Training loss: -1.2249e+00, Test loss: 9.6250e-02, Learning rate: 1.0000e-03
# Epoch 16400, Training loss: -1.1386e+00, Test loss: 9.6091e-02, Learning rate: 1.0000e-03
# Epoch 16500, Training loss: -1.1522e+00, Test loss: 9.6394e-02, Learning rate: 1.0000e-03
# Epoch 16600, Training loss: -1.1814e+00, Test loss: 9.5699e-02, Learning rate: 1.0000e-03
# Epoch 16700, Training loss: -1.1759e+00, Test loss: 9.6107e-02, Learning rate: 1.0000e-03
# Epoch 16800, Training loss: -1.2232e+00, Test loss: 9.5950e-02, Learning rate: 1.0000e-03
# Epoch 16900, Training loss: -1.2034e+00, Test loss: 9.5561e-02, Learning rate: 1.0000e-03
# Epoch 17000, Training loss: -1.2456e+00, Test loss: 9.6047e-02, Learning rate: 1.0000e-03
# Epoch 17100, Training loss: -1.2404e+00, Test loss: 9.6066e-02, Learning rate: 1.0000e-03
# Epoch 17200, Training loss: -1.2150e+00, Test loss: 9.6284e-02, Learning rate: 1.0000e-03
# Epoch 17300, Training loss: -1.2069e+00, Test loss: 9.5713e-02, Learning rate: 1.0000e-03
# Epoch 17400, Training loss: -1.1359e+00, Test loss: 9.5711e-02, Learning rate: 1.0000e-03
# Epoch 17500, Training loss: -1.1438e+00, Test loss: 9.6429e-02, Learning rate: 1.0000e-03
# Epoch 17600, Training loss: -1.2283e+00, Test loss: 9.5525e-02, Learning rate: 1.0000e-03
# Epoch 17700, Training loss: -1.1975e+00, Test loss: 9.6830e-02, Learning rate: 1.0000e-03
# Epoch 17800, Training loss: -1.2242e+00, Test loss: 9.7591e-02, Learning rate: 1.0000e-03
# Epoch 17900, Training loss: -1.2503e+00, Test loss: 9.6288e-02, Learning rate: 1.0000e-03
# Epoch 18000, Training loss: -1.1869e+00, Test loss: 9.5377e-02, Learning rate: 1.0000e-03
# Epoch 18100, Training loss: -1.1860e+00, Test loss: 9.5194e-02, Learning rate: 1.0000e-03
# Epoch 18200, Training loss: -1.1737e+00, Test loss: 9.5336e-02, Learning rate: 1.0000e-03
# Epoch 18300, Training loss: -1.1544e+00, Test loss: 9.6729e-02, Learning rate: 1.0000e-03
# Epoch 18400, Training loss: -1.2047e+00, Test loss: 9.6350e-02, Learning rate: 1.0000e-03
# Epoch 18500, Training loss: -1.1985e+00, Test loss: 9.7339e-02, Learning rate: 1.0000e-03
# Epoch 18600, Training loss: -1.2103e+00, Test loss: 9.5772e-02, Learning rate: 1.0000e-03
# Epoch 18700, Training loss: -1.2045e+00, Test loss: 9.5485e-02, Learning rate: 1.0000e-03
# Epoch 18800, Training loss: -1.1615e+00, Test loss: 9.9649e-02, Learning rate: 1.0000e-03
# Epoch 18900, Training loss: -1.1942e+00, Test loss: 9.5496e-02, Learning rate: 1.0000e-03
# Epoch 19000, Training loss: -1.1923e+00, Test loss: 9.7139e-02, Learning rate: 1.0000e-03
# Epoch 19100, Training loss: -1.2097e+00, Test loss: 9.5232e-02, Learning rate: 1.0000e-03
# Epoch 19200, Training loss: -1.2183e+00, Test loss: 9.5229e-02, Learning rate: 1.0000e-03
# Epoch 19300, Training loss: -1.1392e+00, Test loss: 9.8106e-02, Learning rate: 1.0000e-03
# Epoch 19400, Training loss: -1.2280e+00, Test loss: 9.7159e-02, Learning rate: 1.0000e-03
# Epoch 19500, Training loss: -1.2405e+00, Test loss: 9.5359e-02, Learning rate: 1.0000e-03
# Epoch 19600, Training loss: -1.2297e+00, Test loss: 9.4984e-02, Learning rate: 1.0000e-03
# Epoch 19700, Training loss: -1.2080e+00, Test loss: 9.4965e-02, Learning rate: 1.0000e-03
# Epoch 19800, Training loss: -1.2360e+00, Test loss: 9.4562e-02, Learning rate: 1.0000e-03
# Epoch 19900, Training loss: -1.2000e+00, Test loss: 9.4811e-02, Learning rate: 1.0000e-03
# Epoch 20000, Training loss: -1.1912e+00, Test loss: 9.6766e-02, Learning rate: 1.0000e-03
# Epoch 20100, Training loss: -1.3011e+00, Test loss: 9.4901e-02, Learning rate: 1.0000e-03
# Epoch 20200, Training loss: -1.1633e+00, Test loss: 9.4785e-02, Learning rate: 1.0000e-03
# Epoch 20300, Training loss: -1.1728e+00, Test loss: 9.4950e-02, Learning rate: 1.0000e-03
# Epoch 20400, Training loss: -1.1976e+00, Test loss: 9.4422e-02, Learning rate: 1.0000e-03
# Epoch 20500, Training loss: -1.1606e+00, Test loss: 9.5655e-02, Learning rate: 1.0000e-03
# Epoch 20600, Training loss: -1.2050e+00, Test loss: 9.4411e-02, Learning rate: 1.0000e-03
# Epoch 20700, Training loss: -1.1542e+00, Test loss: 9.4397e-02, Learning rate: 1.0000e-03
# Epoch 20800, Training loss: -1.1640e+00, Test loss: 9.4949e-02, Learning rate: 1.0000e-03
# Epoch 20900, Training loss: -1.1777e+00, Test loss: 9.4508e-02, Learning rate: 1.0000e-03
# Epoch 21000, Training loss: -1.2270e+00, Test loss: 9.5085e-02, Learning rate: 1.0000e-03
# Epoch 21100, Training loss: -1.1759e+00, Test loss: 9.5367e-02, Learning rate: 1.0000e-03
# Epoch 21200, Training loss: -1.1639e+00, Test loss: 9.4331e-02, Learning rate: 1.0000e-03
# Epoch 21300, Training loss: -1.2287e+00, Test loss: 9.4999e-02, Learning rate: 1.0000e-03
# Epoch 21400, Training loss: -1.1919e+00, Test loss: 9.7806e-02, Learning rate: 1.0000e-03
# Epoch 21500, Training loss: -1.1956e+00, Test loss: 9.4851e-02, Learning rate: 1.0000e-03
# Epoch 21600, Training loss: -1.2127e+00, Test loss: 9.5456e-02, Learning rate: 1.0000e-03
# Epoch 21700, Training loss: -1.2454e+00, Test loss: 9.4290e-02, Learning rate: 1.0000e-03
# Epoch 21800, Training loss: -1.2141e+00, Test loss: 9.5697e-02, Learning rate: 1.0000e-03
# Epoch 21900, Training loss: -1.2484e+00, Test loss: 9.4479e-02, Learning rate: 1.0000e-03
# Epoch 22000, Training loss: -1.1526e+00, Test loss: 9.4361e-02, Learning rate: 1.0000e-03
# Epoch 22100, Training loss: -1.0795e+00, Test loss: 9.5237e-02, Learning rate: 1.0000e-03
# Epoch 22200, Training loss: -1.2678e+00, Test loss: 9.4850e-02, Learning rate: 1.0000e-03
# Epoch 22300, Training loss: -1.1353e+00, Test loss: 9.8587e-02, Learning rate: 1.0000e-03
# Epoch 22400, Training loss: -1.1662e+00, Test loss: 9.8121e-02, Learning rate: 1.0000e-03
# Epoch 22500, Training loss: -1.2390e+00, Test loss: 9.4691e-02, Learning rate: 1.0000e-03
# Epoch 22600, Training loss: -1.2316e+00, Test loss: 9.4119e-02, Learning rate: 1.0000e-03
# Epoch 22700, Training loss: -1.1582e+00, Test loss: 9.6712e-02, Learning rate: 1.0000e-03
# Epoch 22800, Training loss: -1.2325e+00, Test loss: 9.5129e-02, Learning rate: 1.0000e-03
# Epoch 22900, Training loss: -1.2155e+00, Test loss: 9.4152e-02, Learning rate: 1.0000e-03
# Epoch 23000, Training loss: -1.1725e+00, Test loss: 9.4541e-02, Learning rate: 1.0000e-03
# Epoch 23100, Training loss: -1.1973e+00, Test loss: 9.7695e-02, Learning rate: 1.0000e-03
# Epoch 23200, Training loss: -1.2735e+00, Test loss: 9.4390e-02, Learning rate: 1.0000e-03
# Epoch 23300, Training loss: -1.1883e+00, Test loss: 9.4631e-02, Learning rate: 1.0000e-03
# Epoch 23400, Training loss: -1.1032e+00, Test loss: 9.4183e-02, Learning rate: 1.0000e-03
# Epoch 23500, Training loss: -1.1494e+00, Test loss: 9.5834e-02, Learning rate: 1.0000e-03
# Epoch 23600, Training loss: -1.1716e+00, Test loss: 9.6482e-02, Learning rate: 1.0000e-03
# Epoch 23700, Training loss: -1.2107e+00, Test loss: 9.4156e-02, Learning rate: 1.0000e-03
# Epoch 23800, Training loss: -1.2098e+00, Test loss: 9.4705e-02, Learning rate: 1.0000e-03
# Epoch 23900, Training loss: -1.1807e+00, Test loss: 9.4401e-02, Learning rate: 1.0000e-03
# Epoch 24000, Training loss: -1.2509e+00, Test loss: 9.4297e-02, Learning rate: 1.0000e-03
# Epoch 24100, Training loss: -1.1835e+00, Test loss: 9.5833e-02, Learning rate: 1.0000e-03
# Epoch 24200, Training loss: -1.2119e+00, Test loss: 9.5442e-02, Learning rate: 1.0000e-03
# Epoch 24300, Training loss: -1.1675e+00, Test loss: 9.4648e-02, Learning rate: 1.0000e-03
# Epoch 24400, Training loss: -1.1984e+00, Test loss: 9.3766e-02, Learning rate: 1.0000e-03
# Epoch 24500, Training loss: -1.1669e+00, Test loss: 9.4209e-02, Learning rate: 1.0000e-03
# Epoch 24600, Training loss: -1.2263e+00, Test loss: 9.7019e-02, Learning rate: 1.0000e-03
# Epoch 24700, Training loss: -1.2076e+00, Test loss: 9.3752e-02, Learning rate: 1.0000e-03
# Epoch 24800, Training loss: -1.2099e+00, Test loss: 9.4308e-02, Learning rate: 1.0000e-03
# Epoch 24900, Training loss: -1.1881e+00, Test loss: 9.3904e-02, Learning rate: 1.0000e-03
# Epoch 25000, Training loss: -1.2339e+00, Test loss: 9.5648e-02, Learning rate: 1.0000e-03
# Epoch 25100, Training loss: -1.1493e+00, Test loss: 9.5528e-02, Learning rate: 1.0000e-03
# Epoch 25200, Training loss: -1.1957e+00, Test loss: 9.4261e-02, Learning rate: 1.0000e-03
# Epoch 25300, Training loss: -1.1416e+00, Test loss: 9.3863e-02, Learning rate: 1.0000e-03
# Epoch 25400, Training loss: -1.1983e+00, Test loss: 9.4172e-02, Learning rate: 1.0000e-03
# Epoch 25500, Training loss: -1.2627e+00, Test loss: 9.3791e-02, Learning rate: 1.0000e-03
# Epoch 25600, Training loss: -1.2645e+00, Test loss: 9.4214e-02, Learning rate: 1.0000e-03
# Epoch 25700, Training loss: -1.1641e+00, Test loss: 9.3820e-02, Learning rate: 1.0000e-03
# Epoch 25800, Training loss: -1.1878e+00, Test loss: 9.4402e-02, Learning rate: 1.0000e-03
# Epoch 25900, Training loss: -1.1693e+00, Test loss: 9.3817e-02, Learning rate: 1.0000e-03
# Epoch 26000, Training loss: -1.2439e+00, Test loss: 9.3632e-02, Learning rate: 1.0000e-03
# Epoch 26100, Training loss: -1.1943e+00, Test loss: 9.5595e-02, Learning rate: 1.0000e-03
# Epoch 26200, Training loss: -1.2321e+00, Test loss: 9.3752e-02, Learning rate: 1.0000e-03
# Epoch 26300, Training loss: -1.2022e+00, Test loss: 9.4095e-02, Learning rate: 1.0000e-03
# Epoch 26400, Training loss: -1.1753e+00, Test loss: 9.3531e-02, Learning rate: 1.0000e-03
# Epoch 26500, Training loss: -1.2111e+00, Test loss: 9.4101e-02, Learning rate: 1.0000e-03
# Epoch 26600, Training loss: -1.2089e+00, Test loss: 9.3991e-02, Learning rate: 1.0000e-03
# Epoch 26700, Training loss: -1.2079e+00, Test loss: 9.4599e-02, Learning rate: 1.0000e-03
# Epoch 26800, Training loss: -1.1899e+00, Test loss: 9.3810e-02, Learning rate: 1.0000e-03
# Epoch 26900, Training loss: -1.1898e+00, Test loss: 9.3702e-02, Learning rate: 1.0000e-03
# Epoch 27000, Training loss: -1.1914e+00, Test loss: 9.3675e-02, Learning rate: 1.0000e-03
# Epoch 27100, Training loss: -1.2140e+00, Test loss: 9.4035e-02, Learning rate: 1.0000e-03
# Epoch 27200, Training loss: -1.1945e+00, Test loss: 9.4452e-02, Learning rate: 1.0000e-03
# Epoch 27300, Training loss: -1.1344e+00, Test loss: 9.7839e-02, Learning rate: 1.0000e-03
# Epoch 27400, Training loss: -1.2449e+00, Test loss: 9.3291e-02, Learning rate: 1.0000e-03
# Epoch 27500, Training loss: -1.1832e+00, Test loss: 9.6065e-02, Learning rate: 1.0000e-03
# Epoch 27600, Training loss: -1.2219e+00, Test loss: 9.3496e-02, Learning rate: 1.0000e-03
# Epoch 27700, Training loss: -1.2320e+00, Test loss: 9.3253e-02, Learning rate: 1.0000e-03
# Epoch 27800, Training loss: -1.1422e+00, Test loss: 9.3796e-02, Learning rate: 1.0000e-03
# Epoch 27900, Training loss: -1.2589e+00, Test loss: 9.3326e-02, Learning rate: 1.0000e-03
# Epoch 28000, Training loss: -1.2326e+00, Test loss: 9.3696e-02, Learning rate: 1.0000e-03
# Epoch 28100, Training loss: -1.2121e+00, Test loss: 9.3873e-02, Learning rate: 1.0000e-03
# Epoch 28200, Training loss: -1.2727e+00, Test loss: 9.3370e-02, Learning rate: 1.0000e-03
# Epoch 28300, Training loss: -1.1785e+00, Test loss: 9.3622e-02, Learning rate: 1.0000e-03
# Epoch 28400, Training loss: -1.1680e+00, Test loss: 9.4300e-02, Learning rate: 1.0000e-03
# Epoch 28500, Training loss: -1.1652e+00, Test loss: 9.5056e-02, Learning rate: 1.0000e-03
# Epoch 28600, Training loss: -1.1272e+00, Test loss: 9.3073e-02, Learning rate: 1.0000e-03
# Epoch 28700, Training loss: -1.1906e+00, Test loss: 9.5513e-02, Learning rate: 1.0000e-03
# Epoch 28800, Training loss: -1.2006e+00, Test loss: 9.4328e-02, Learning rate: 1.0000e-03
# Epoch 28900, Training loss: -1.2098e+00, Test loss: 9.3553e-02, Learning rate: 1.0000e-03
# Epoch 29000, Training loss: -1.1921e+00, Test loss: 1.0075e-01, Learning rate: 1.0000e-03
# Epoch 29100, Training loss: -1.1929e+00, Test loss: 9.3229e-02, Learning rate: 1.0000e-03
# Epoch 29200, Training loss: -1.2361e+00, Test loss: 9.2885e-02, Learning rate: 1.0000e-03
# Epoch 29300, Training loss: -1.1653e+00, Test loss: 9.3473e-02, Learning rate: 1.0000e-03
# Epoch 29400, Training loss: -1.3048e+00, Test loss: 9.2899e-02, Learning rate: 1.0000e-03
# Epoch 29500, Training loss: -1.2613e+00, Test loss: 9.2338e-02, Learning rate: 1.0000e-03
# Epoch 29600, Training loss: -1.2324e+00, Test loss: 9.3735e-02, Learning rate: 1.0000e-03
# Epoch 29700, Training loss: -1.1517e+00, Test loss: 9.4598e-02, Learning rate: 1.0000e-03
# Epoch 29800, Training loss: -1.1579e+00, Test loss: 9.3876e-02, Learning rate: 1.0000e-03
# Epoch 29900, Training loss: -1.1622e+00, Test loss: 9.5397e-02, Learning rate: 1.0000e-03
# Epoch 30000, Training loss: -1.1836e+00, Test loss: 9.4305e-02, Learning rate: 1.0000e-03
# Epoch 30100, Training loss: -1.2231e+00, Test loss: 9.3907e-02, Learning rate: 1.0000e-03
# Epoch 30200, Training loss: -1.1321e+00, Test loss: 9.4260e-02, Learning rate: 1.0000e-03
# Epoch 30300, Training loss: -1.2205e+00, Test loss: 9.3776e-02, Learning rate: 1.0000e-03
# Epoch 30400, Training loss: -1.2713e+00, Test loss: 9.4272e-02, Learning rate: 1.0000e-03
# Epoch 30500, Training loss: -1.2248e+00, Test loss: 9.2552e-02, Learning rate: 1.0000e-03
# Epoch 30600, Training loss: -1.1465e+00, Test loss: 9.2360e-02, Learning rate: 1.0000e-03
# Epoch 30700, Training loss: -1.1715e+00, Test loss: 9.2384e-02, Learning rate: 1.0000e-03
# Epoch 30800, Training loss: -1.2540e+00, Test loss: 9.2841e-02, Learning rate: 1.0000e-03
# Epoch 30900, Training loss: -1.2324e+00, Test loss: 9.2286e-02, Learning rate: 1.0000e-03
# Epoch 31000, Training loss: -1.1795e+00, Test loss: 9.5126e-02, Learning rate: 1.0000e-03
# Epoch 31100, Training loss: -1.2366e+00, Test loss: 9.1972e-02, Learning rate: 1.0000e-03
# Epoch 31200, Training loss: -1.1256e+00, Test loss: 9.6303e-02, Learning rate: 1.0000e-03
# Epoch 31300, Training loss: -1.1961e+00, Test loss: 9.3773e-02, Learning rate: 1.0000e-03
# Epoch 31400, Training loss: -1.2435e+00, Test loss: 9.2729e-02, Learning rate: 1.0000e-03
# Epoch 31500, Training loss: -1.2215e+00, Test loss: 9.2373e-02, Learning rate: 1.0000e-03
# Epoch 31600, Training loss: -1.1768e+00, Test loss: 9.2372e-02, Learning rate: 1.0000e-03
# Epoch 31700, Training loss: -1.2268e+00, Test loss: 9.3974e-02, Learning rate: 1.0000e-03
# Epoch 31800, Training loss: -1.2279e+00, Test loss: 9.5437e-02, Learning rate: 1.0000e-03
# Epoch 31900, Training loss: -1.1962e+00, Test loss: 9.3050e-02, Learning rate: 1.0000e-03
# Epoch 32000, Training loss: -1.1461e+00, Test loss: 9.5914e-02, Learning rate: 1.0000e-03
# Epoch 32100, Training loss: -1.1822e+00, Test loss: 9.2673e-02, Learning rate: 1.0000e-03
# Epoch 32200, Training loss: -1.1580e+00, Test loss: 9.3919e-02, Learning rate: 1.0000e-03
# Epoch 32300, Training loss: -1.2183e+00, Test loss: 9.2502e-02, Learning rate: 1.0000e-03
# Epoch 32400, Training loss: -1.2424e+00, Test loss: 9.2136e-02, Learning rate: 1.0000e-03
# Epoch 32500, Training loss: -1.1805e+00, Test loss: 9.3642e-02, Learning rate: 1.0000e-03
# Epoch 32600, Training loss: -1.2075e+00, Test loss: 9.1880e-02, Learning rate: 1.0000e-03
# Epoch 32700, Training loss: -1.1897e+00, Test loss: 9.5359e-02, Learning rate: 1.0000e-03
# Epoch 32800, Training loss: -1.1752e+00, Test loss: 9.1506e-02, Learning rate: 1.0000e-03
# Epoch 32900, Training loss: -1.2223e+00, Test loss: 9.1620e-02, Learning rate: 1.0000e-03
# Epoch 33000, Training loss: -1.1798e+00, Test loss: 9.1545e-02, Learning rate: 1.0000e-03
# Epoch 33100, Training loss: -1.1749e+00, Test loss: 9.1305e-02, Learning rate: 1.0000e-03
# Epoch 33200, Training loss: -1.1628e+00, Test loss: 9.1720e-02, Learning rate: 1.0000e-03
# Epoch 33300, Training loss: -1.1326e+00, Test loss: 9.6318e-02, Learning rate: 1.0000e-03
# Epoch 33400, Training loss: -1.2054e+00, Test loss: 9.3333e-02, Learning rate: 1.0000e-03
# Epoch 33500, Training loss: -1.1973e+00, Test loss: 9.1503e-02, Learning rate: 1.0000e-03
# Epoch 33600, Training loss: -1.2218e+00, Test loss: 9.1832e-02, Learning rate: 1.0000e-03
# Epoch 33700, Training loss: -1.1439e+00, Test loss: 9.2151e-02, Learning rate: 1.0000e-03
# Epoch 33800, Training loss: -1.1991e+00, Test loss: 9.2426e-02, Learning rate: 1.0000e-03
# Epoch 33900, Training loss: -1.2334e+00, Test loss: 9.1650e-02, Learning rate: 1.0000e-03
# Epoch 34000, Training loss: -1.1978e+00, Test loss: 9.2187e-02, Learning rate: 1.0000e-03
# Epoch 34100, Training loss: -1.2578e+00, Test loss: 9.1701e-02, Learning rate: 1.0000e-03
# Epoch 34200, Training loss: -1.1985e+00, Test loss: 9.5824e-02, Learning rate: 1.0000e-03
# Epoch 34300, Training loss: -1.1477e+00, Test loss: 9.1736e-02, Learning rate: 1.0000e-03
# Epoch 34400, Training loss: -1.2874e+00, Test loss: 9.4021e-02, Learning rate: 1.0000e-03
# Epoch 34500, Training loss: -1.1890e+00, Test loss: 9.1537e-02, Learning rate: 1.0000e-03
# Epoch 34600, Training loss: -1.1173e+00, Test loss: 9.2947e-02, Learning rate: 1.0000e-03
# Epoch 34700, Training loss: -1.1851e+00, Test loss: 9.3015e-02, Learning rate: 1.0000e-03
# Epoch 34800, Training loss: -1.1596e+00, Test loss: 9.0784e-02, Learning rate: 1.0000e-03
# Epoch 34900, Training loss: -1.0943e+00, Test loss: 9.1485e-02, Learning rate: 1.0000e-03

# %%
fig, axs = plt.subplots(1, 1, figsize=(8, 5))
axs.plot(test_loss, color='blue')
axs.set_ylim(5e-2, 1e0)
axs.set_xlabel('Iteration')
axs.set_ylabel('Relative Error')
axs.set_xscale('log')
axs.set_yscale('log')
axs.set_title('Monitoring Error')
# Out:
# Text(0.5, 1.0, 'Monitoring Error')

# %% [markdown]
# ### Test

# %%
# Load data
special_test = np.array(pd.read_csv('Dataset/special_test.csv').values)

# Compare the results of using the initial neural network and the final neural network
x_exact = np.linspace(0, 1, 100)

fig, axs = plt.subplots(1, 3, figsize=(21, 5), dpi=300)


for i in range(len(special_test)):
    nodes_fullNN, u_fullNN = FEM_sol(trained_param, special_test[i])
    
    ritz_fullNN = solve_and_loss(forward_pass(special_test[i], trained_param), special_test[i])
    exact_ritz_val = Exact_Ritz(np.array(special_test[i][0]), np.array(special_test[i][1]))
    u_exact = np.arctan(special_test[i][0] * (x_exact - special_test[i][1])) + np.arctan(special_test[i][0] * special_test[i][1])
    
    ax = axs[i]
    ax.plot(x_exact, u_exact, 'k', label=f'Exact Ritz = {Exact_Ritz(np.array(special_test[i][0]), np.array(special_test[i][1])):.4f}')
    ax.plot(nodes_fullNN, u_fullNN, 'o', color='b')

    ax.set_xlabel('x')
    ax.set_ylabel('u')
    ax.legend([f'Exact Ritz = {exact_ritz_val:.4f}', 
               f'Ritz NN param = {ritz_fullNN:.4f}',]) 
    ax.set_title(rf'Comparison using $\alpha$ = {special_test[i][0]:.4f} and s = {special_test[i][1]:.4f}')
    
plt.tight_layout()
plt.show()

# %%
# Evaluate the NN in every test data and then compare the loss with the exact Ritz value

# List to save the Ritz values
ritz_test        = []
exact_ritz_test  = []
error_test       = []
rel_error_test   = []
rel_uniform_test = []

# Evaluate the NN in every test data
for i in range(len(test_data)):
    
    # Calculate the Ritz value
    ritz = solve_and_loss(forward_pass(test_data[i], trained_param), test_data[i])
    ritz_test.append(ritz)
    
    # Calculate the exact Ritz value
    exact_ritz = Exact_Ritz(test_data[i][0], test_data[i][1])
    exact_ritz_test.append(exact_ritz)
    exact_ritz_bal = exact_ritz / ritz_dict_test[str(test_data[i])]

    # Calculate the error
    error = np.sqrt(abs((ritz - exact_ritz)/ritz_dict_test[str(test_data[i])]))
    error_test.append(error)

    # Calculate the relative error
    rel_error = error / np.sqrt(abs(exact_ritz_bal))
    rel_error_test.append(rel_error)
    
    # Calculate the relative error with the uniform grid
    rel_error_uni = np.sqrt(abs( (ritz_dict_test[str(test_data[i])] - exact_ritz) / exact_ritz ))
    rel_uniform_test.append(rel_error_uni)

# Evaluate the NN in every training data and then compare the loss with the exact Ritz value

# List to save the Ritz values
ritz_train          = []
exact_ritz_train    = []
error_train         = []
rel_error_train     = []
rel_uniform_train   = []

# Evaluate the NN in every training data
for i in range(len(train_data)):
    
    # Calculate the Ritz value
    ritz = solve_and_loss(forward_pass(train_data[i], trained_param), train_data[i])
    ritz_train.append(ritz)
    
    # Calculate the exact Ritz value
    exact_ritz = Exact_Ritz(train_data[i][0], train_data[i][1])
    exact_ritz_train.append(exact_ritz)
    exact_ritz_bal = exact_ritz / ritz_dict_train[str(train_data[i])]

    # Calculate the error
    error = np.sqrt(abs((ritz - exact_ritz)/ritz_dict_train[str(train_data[i])]))
    error_train.append(error)

    # Calculate the relative error
    rel_error = error / np.sqrt(abs(exact_ritz_bal))
    rel_error_train.append(rel_error)

    # Calculate the relative error with the uniform grid
    rel_error_uni = np.sqrt(abs( (ritz_dict_train[str(train_data[i])] - exact_ritz) / exact_ritz ))
    rel_uniform_train.append(rel_error_uni)

# %%
# Compute statistics for the training set
train_mean_abs_error = np.mean(error_train)
train_mean_rel_error = np.mean(rel_error_train)
train_std_abs_error = np.std(error_train)
train_std_rel_error = np.std(rel_error_train)
train_max_abs_error = np.max(error_train)
train_max_rel_error = np.max(rel_error_train)
train_uniform_mean_rel_error = np.mean(rel_uniform_train) 
train_uniform_max_rel_error = np.max(rel_uniform_train)

# Compute statistics for the test set
val_mean_abs_error = np.mean(error_test)
val_mean_rel_error = np.mean(rel_error_test)
val_std_abs_error = np.std(error_test)
val_std_rel_error = np.std(rel_error_test)
val_max_abs_error = np.max(error_test)
val_max_rel_error = np.max(rel_error_test)
val_uniform_mean_rel_error = np.mean(rel_uniform_test)
val_uniform_max_rel_error = np.max(rel_uniform_test)

# Create a DataFrame to summarize the errors
data = {
    'Set': ['Train', 'Test'],
    'Mean Absolute Error': [train_mean_abs_error, val_mean_abs_error],
    'Mean Relative Error': [train_mean_rel_error, val_mean_rel_error],
    'Std Absolute Error': [train_std_abs_error, val_std_abs_error],
    'Std Relative Error': [train_std_rel_error, val_std_rel_error],
    'Max Absolute Error': [train_max_abs_error, val_max_abs_error],
    'Max Relative Error': [train_max_rel_error, val_max_rel_error],
    'Uniform grid Mean Relative error': [train_uniform_mean_rel_error, val_uniform_mean_rel_error],
    'Uniform grid Max Relative error': [train_uniform_max_rel_error, val_uniform_max_rel_error]
}

df_errors = pd.DataFrame(data)
df_errors
# Out:
#      Set  Mean Absolute Error  Mean Relative Error  Std Absolute Error  \
# 0  Train             0.097468             0.088703            0.015444
# 1   Test             0.097581             0.088752            0.015617
#
#    Std Relative Error  Max Absolute Error  Max Relative Error  \
# 0            0.011961            0.125612            0.108863
# 1            0.012133            0.124976            0.108416
#
#    Uniform grid Mean Relative error  Uniform grid Max Relative error
# 0                          0.376985                         0.583681
# 1                          0.377729                         0.583146
