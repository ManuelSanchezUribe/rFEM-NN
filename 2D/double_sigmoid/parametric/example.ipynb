# %%
#########################################################################################################
# An r-adaptive finite element method using neural networks for parametric self-adjoint elliptic problems
# Author: Danilo Aballay, Federico Fuentes, Vicente Iligaray, Ángel J. Omella,
#         David Pardo, Manuel A. Sánchez, Ignacio Tapia, Carlos Uriarte
#########################################################################################################


import jax.numpy as jnp
from jax import random, grad, jit, vmap
import jax
import jax.nn as nn
import numpy as np
from jax.example_libraries import optimizers
import matplotlib.pyplot as plt
import pandas as pd
import os
import sys
from fem_system import solve, solve_and_loss, solve_and_loss_scipy, build_system_vmap

os.environ["TF_ENABLE_ONEDNN_OPTS"] = "1"
os.environ["JAX_PLATFORMS"] = "cpu"
os.environ["KERAS_BACKEND"] = "jax"
import keras

# Set the random seed
keras.utils.set_random_seed(1234)

dtype='float64' # double precision set to default in the SCR functions
jax.config.update("jax_enable_x64", True)
keras.backend.set_floatx(dtype)


sys.path.append(os.path.abspath('..'))
key = jax.random.PRNGKey(0)

# %% [markdown]
# ## Import dataset

# %%
dataset       = np.array(pd.read_csv('Dataset/dataset.csv').values)
train_indices = np.array(pd.read_csv('Dataset/train_indices.csv').train_indices)
test_indices  = np.array(pd.read_csv('Dataset/test_indices.csv').test_indices)

train_data   = dataset[train_indices]
test_data    = dataset[test_indices]
subset_test  = np.array(pd.read_csv('Dataset/test_subset.csv').values)

# %% [markdown]
# ### Rutina para guardar el Ritz usando grilla uniforme

# %%
from scipy.integrate import dblquad, quad
import numpy as onp

def Exact_Ritz(alpha, sx, sy):
    u      = lambda x, y: (onp.arctan(alpha*(x - sx)) + onp.arctan(alpha*sx))*(onp.arctan(alpha*(y - sy)) + onp.arctan(alpha*sy))
    f      = lambda x, y: (onp.arctan(alpha*(y - sy)) + onp.arctan(alpha*sy))*2*alpha**2*(alpha*(x-sx))/(1 + (alpha*(x - sx))**2)**2 \
          + (onp.arctan(alpha*(x - sx)) + onp.arctan(alpha*sx))*2*alpha**2*(alpha*(y-sy))/(1 + (alpha*(y - sy))**2)**2
    gu     = lambda x, y: (onp.arctan(alpha*(x-sx)) + onp.arctan(alpha*sx)) * alpha / (1 + (alpha*(y-sy))**2)
    gt     = lambda x, y: (onp.arctan(alpha*(y-sy)) + onp.arctan(alpha*sy)) * alpha / (1 + (alpha*(x-sx))**2) 
    gradu = lambda x, y: gu(x, y)**2 + gt(x, y)**2

    neum1 = quad(lambda x: u(x, 1)*gu(x, 1), 0, 1)
    neum2 = quad(lambda x: u(1, x)*gt(1, x), 0, 1)

    fun = lambda y, x: 0.5*gradu(x, y) - u(x, y)*f(x, y) 
    return dblquad(fun, 0, 1, 0, 1)[0] - neum1[0] - neum2[0]

# %%
# Define the number of nodes
n_nodes       = 2*9 # 2*(number of elements [N])
uniform_grid  = jnp.concatenate([jnp.linspace(0, 1, n_nodes//2 + 1), jnp.linspace(0, 1, n_nodes//2 + 1)])

# %%
# Compute the ritz value with uniform mesh for training set
ritz_dict_train = {str(a): solve_and_loss_scipy(uniform_grid, a.reshape(-1,3)) for a in np.concatenate((train_data, subset_test))}

# Compute the ritz value with uniform mesh for test set
ritz_dict_val = {str(a): solve_and_loss_scipy(uniform_grid, a.reshape(-1,3)) for a in test_data}

# %% [markdown]
# ### Neural Network

# %%
# Neural Network parameters

def init_params(layers, key):
    Ws = []
    bs = []
    for i in range(len(layers) - 1):
        std_lecun = jnp.sqrt(1 / layers[i])
        key, subkey = random.split(key)
        Ws.append(random.normal(subkey, (layers[i], layers[i + 1])) * std_lecun)
        bs.append(jnp.zeros(layers[i + 1]))
    return [Ws, bs]

@jit
def forward_pass(A_t, params):
    Ws, bs = params
    H = A_t
    for i in range(len(Ws) - 1):
        H = jnp.matmul(H, Ws[i]) + bs[i]
        H = jnp.tanh(H)
    nodes_ = jnp.matmul(H, Ws[-1]) + bs[-1]
    n_n = nodes_.size
    thetax = nn.softmax(nodes_[:n_n//2])
    thetay = nn.softmax(nodes_[n_n//2:])
    nodesx = jnp.cumsum(thetax)
    nodesx = jnp.insert(nodesx, 0, 0)
    nodesy = jnp.cumsum(thetay)
    nodesy = jnp.insert(nodesy, 0, 0)
    return jnp.concatenate([nodesx, nodesy])

def loss(params, alphas):
    losses = solve_and_loss_scipy(forward_pass(alphas[0], params), alphas[0].reshape(-1, 3))
    return jnp.array([losses[i] / abs(ritz_dict_train[str(alpha)]) for i, alpha in enumerate(alphas)]).mean()

def loss_test(params, alphas, J_u):
    temp = 0
    for i in range(len(alphas)):
        val = solve_and_loss_scipy(forward_pass(alphas[i,:], params), alphas[i,:].reshape(-1, 3)).item()
        temp += np.sqrt(abs((J_u[i]-val)/J_u[i]))
    return temp/len(alphas)

def FEM_sol(params, alpha):
    nodes = forward_pass(alpha, params)
    return solve(nodes, jnp.squeeze(alpha))

def train(loss_fn, opt_state, alphas, test_subset, n_epochs=10, n_iter_per_epoch=1000, batch_size=1, lr=1e-2):
    train_loss = []
    test_loss  = []
    test_loss_epoch = []
    J_u        = jnp.array([Exact_Ritz(subset_test[i,0], subset_test[i,1], subset_test[i,2]) for i in range(len(subset_test))])
    key = random.PRNGKey(100)
    n_alphas = alphas.shape[0]
    opt_init, opt_update, get_params = optimizers.adam(lr)
    params   = get_params(opt_state)
    test_loss_save_interval = 100
    
    for epoch in range(n_epochs):
        key, subkey = random.split(key)
        idx = random.choice(subkey, n_alphas, (batch_size,), replace=False)
        sigma_batch = alphas[idx]

        for it in range(n_iter_per_epoch):
            params    = get_params(opt_state)
            grads     = grad(loss_fn)(params, sigma_batch)
            opt_state = opt_update(0, grads, opt_state)

        if epoch == 100:
            test_loss_save_interval = 10
        if epoch == 1000:
            test_loss_save_interval = 100
        if epoch == 10000:
            test_loss_save_interval = 1000

        if epoch == 210000:
            lr  = 1e-3
            opt_init, opt_update, get_params = optimizers.adam(lr)
            opt_state = opt_init(params)
        
        params = get_params(opt_state)
        loss_val = loss_fn(params, sigma_batch)
        train_loss.append(loss_val)

        if epoch % test_loss_save_interval == 0:
            test_loss_epoch.append(epoch)
            test_loss.append(loss_test(params, test_subset, J_u))
            print(f"Epoch {epoch}, Training loss: {loss_val:.4e}, Test loss: {test_loss[-1]:.4e}, Learning rate: {lr:.4e}")

    return get_params(opt_state), opt_state, train_loss, test_loss, test_loss_epoch

# %% [markdown]
# ### Training

# %%
# Network parameters and training configuration
iter       = 1  # Number of iterations per epoch
epochs     = 15000
lr         = 1e-2
batch_size = 1

# Define the neural network architecture
layers = [3, 10, 10, n_nodes]
key    = random.PRNGKey(42)

# Initialize the optimizer and parameters
opt_init, opt_update, get_params = optimizers.adam(lr)
params    = init_params(layers, key)
opt_state = opt_init(params)

# Train the model
trained_param, opt_state_save, trained_error, test_loss, test_loss_epoch = train(loss, opt_state, jnp.array(train_data), jnp.array(subset_test), epochs, iter, batch_size, lr)
# Out:
# Epoch 0, Training loss: -9.7911e-01, Test loss: 3.1196e-01, Learning rate: 1.0000e-02
# Epoch 100, Training loss: -1.0229e+00, Test loss: 3.3281e-01, Learning rate: 1.0000e-02
# Epoch 110, Training loss: -9.9990e-01, Test loss: 3.4729e-01, Learning rate: 1.0000e-02
# Epoch 120, Training loss: -9.9959e-01, Test loss: 3.4303e-01, Learning rate: 1.0000e-02
# Epoch 130, Training loss: -1.1521e+00, Test loss: 3.2250e-01, Learning rate: 1.0000e-02
# Epoch 140, Training loss: -9.5542e-01, Test loss: 3.1677e-01, Learning rate: 1.0000e-02
# Epoch 150, Training loss: -9.6543e-01, Test loss: 3.1297e-01, Learning rate: 1.0000e-02
# Epoch 160, Training loss: -9.7164e-01, Test loss: 2.8255e-01, Learning rate: 1.0000e-02
# Epoch 170, Training loss: -9.8283e-01, Test loss: 2.8608e-01, Learning rate: 1.0000e-02
# Epoch 180, Training loss: -1.0092e+00, Test loss: 2.8736e-01, Learning rate: 1.0000e-02
# Epoch 190, Training loss: -9.5988e-01, Test loss: 2.9088e-01, Learning rate: 1.0000e-02
# Epoch 200, Training loss: -1.0283e+00, Test loss: 3.0333e-01, Learning rate: 1.0000e-02
# Epoch 210, Training loss: -9.6641e-01, Test loss: 2.8675e-01, Learning rate: 1.0000e-02
# Epoch 220, Training loss: -1.0072e+00, Test loss: 2.9055e-01, Learning rate: 1.0000e-02
# Epoch 230, Training loss: -1.0301e+00, Test loss: 2.9542e-01, Learning rate: 1.0000e-02
# Epoch 240, Training loss: -9.6219e-01, Test loss: 2.8866e-01, Learning rate: 1.0000e-02
# Epoch 250, Training loss: -1.0310e+00, Test loss: 2.9709e-01, Learning rate: 1.0000e-02
# Epoch 260, Training loss: -9.9547e-01, Test loss: 3.2132e-01, Learning rate: 1.0000e-02
# Epoch 270, Training loss: -1.0419e+00, Test loss: 3.1977e-01, Learning rate: 1.0000e-02
# Epoch 280, Training loss: -9.8107e-01, Test loss: 3.0257e-01, Learning rate: 1.0000e-02
# Epoch 290, Training loss: -1.0011e+00, Test loss: 3.0140e-01, Learning rate: 1.0000e-02
# Epoch 300, Training loss: -9.9972e-01, Test loss: 3.0521e-01, Learning rate: 1.0000e-02
# Epoch 310, Training loss: -9.9378e-01, Test loss: 3.0798e-01, Learning rate: 1.0000e-02
# Epoch 320, Training loss: -1.0153e+00, Test loss: 3.0598e-01, Learning rate: 1.0000e-02
# Epoch 330, Training loss: -1.1079e+00, Test loss: 3.1692e-01, Learning rate: 1.0000e-02
# Epoch 340, Training loss: -1.1009e+00, Test loss: 3.2114e-01, Learning rate: 1.0000e-02
# Epoch 350, Training loss: -1.0217e+00, Test loss: 3.1605e-01, Learning rate: 1.0000e-02
# Epoch 360, Training loss: -8.4173e-01, Test loss: 2.9488e-01, Learning rate: 1.0000e-02
# Epoch 370, Training loss: -1.0000e+00, Test loss: 3.2549e-01, Learning rate: 1.0000e-02
# Epoch 380, Training loss: -1.0031e+00, Test loss: 3.2164e-01, Learning rate: 1.0000e-02
# Epoch 390, Training loss: -9.9790e-01, Test loss: 3.2380e-01, Learning rate: 1.0000e-02
# Epoch 400, Training loss: -1.0290e+00, Test loss: 3.0223e-01, Learning rate: 1.0000e-02
# Epoch 410, Training loss: -9.4908e-01, Test loss: 3.1331e-01, Learning rate: 1.0000e-02
# Epoch 420, Training loss: -9.9826e-01, Test loss: 3.1215e-01, Learning rate: 1.0000e-02
# Epoch 430, Training loss: -1.0063e+00, Test loss: 3.1211e-01, Learning rate: 1.0000e-02
# Epoch 440, Training loss: -9.8450e-01, Test loss: 3.0853e-01, Learning rate: 1.0000e-02
# Epoch 450, Training loss: -9.8482e-01, Test loss: 3.0031e-01, Learning rate: 1.0000e-02
# Epoch 460, Training loss: -9.9998e-01, Test loss: 2.9066e-01, Learning rate: 1.0000e-02
# Epoch 470, Training loss: -1.0442e+00, Test loss: 2.8633e-01, Learning rate: 1.0000e-02
# Epoch 480, Training loss: -9.9781e-01, Test loss: 2.7580e-01, Learning rate: 1.0000e-02
# Epoch 490, Training loss: -1.0467e+00, Test loss: 2.7356e-01, Learning rate: 1.0000e-02
# Epoch 500, Training loss: -1.0355e+00, Test loss: 2.6725e-01, Learning rate: 1.0000e-02
# Epoch 510, Training loss: -1.0157e+00, Test loss: 2.6692e-01, Learning rate: 1.0000e-02
# Epoch 520, Training loss: -9.3401e-01, Test loss: 2.7533e-01, Learning rate: 1.0000e-02
# Epoch 530, Training loss: -9.8474e-01, Test loss: 2.7523e-01, Learning rate: 1.0000e-02
# Epoch 540, Training loss: -9.9997e-01, Test loss: 2.7325e-01, Learning rate: 1.0000e-02
# Epoch 550, Training loss: -9.8524e-01, Test loss: 2.6681e-01, Learning rate: 1.0000e-02
# Epoch 560, Training loss: -9.5753e-01, Test loss: 2.6413e-01, Learning rate: 1.0000e-02
# Epoch 570, Training loss: -1.0033e+00, Test loss: 2.6320e-01, Learning rate: 1.0000e-02
# Epoch 580, Training loss: -1.0154e+00, Test loss: 2.5737e-01, Learning rate: 1.0000e-02
# Epoch 590, Training loss: -1.0073e+00, Test loss: 2.6294e-01, Learning rate: 1.0000e-02
# Epoch 600, Training loss: -9.9218e-01, Test loss: 2.6116e-01, Learning rate: 1.0000e-02
# Epoch 610, Training loss: -9.9999e-01, Test loss: 2.6223e-01, Learning rate: 1.0000e-02
# Epoch 620, Training loss: -1.0087e+00, Test loss: 2.5867e-01, Learning rate: 1.0000e-02
# Epoch 630, Training loss: -9.9878e-01, Test loss: 2.6244e-01, Learning rate: 1.0000e-02
# Epoch 640, Training loss: -9.4881e-01, Test loss: 2.5766e-01, Learning rate: 1.0000e-02
# Epoch 650, Training loss: -1.0924e+00, Test loss: 2.5378e-01, Learning rate: 1.0000e-02
# Epoch 660, Training loss: -1.0127e+00, Test loss: 2.6060e-01, Learning rate: 1.0000e-02
# Epoch 670, Training loss: -9.6450e-01, Test loss: 2.6628e-01, Learning rate: 1.0000e-02
# Epoch 680, Training loss: -1.0873e+00, Test loss: 2.6877e-01, Learning rate: 1.0000e-02
# Epoch 690, Training loss: -1.0008e+00, Test loss: 2.7585e-01, Learning rate: 1.0000e-02
# Epoch 700, Training loss: -1.0030e+00, Test loss: 2.6346e-01, Learning rate: 1.0000e-02
# Epoch 710, Training loss: -9.6960e-01, Test loss: 2.6263e-01, Learning rate: 1.0000e-02
# Epoch 720, Training loss: -1.0548e+00, Test loss: 2.6246e-01, Learning rate: 1.0000e-02
# Epoch 730, Training loss: -9.9537e-01, Test loss: 2.5443e-01, Learning rate: 1.0000e-02
# Epoch 740, Training loss: -1.0051e+00, Test loss: 2.6124e-01, Learning rate: 1.0000e-02
# Epoch 750, Training loss: -9.7755e-01, Test loss: 2.6669e-01, Learning rate: 1.0000e-02
# Epoch 760, Training loss: -1.0557e+00, Test loss: 2.6492e-01, Learning rate: 1.0000e-02
# Epoch 770, Training loss: -9.8976e-01, Test loss: 2.6478e-01, Learning rate: 1.0000e-02
# Epoch 780, Training loss: -9.8910e-01, Test loss: 2.7175e-01, Learning rate: 1.0000e-02
# Epoch 790, Training loss: -1.0072e+00, Test loss: 2.6049e-01, Learning rate: 1.0000e-02
# Epoch 800, Training loss: -1.0107e+00, Test loss: 2.5871e-01, Learning rate: 1.0000e-02
# Epoch 810, Training loss: -9.9758e-01, Test loss: 2.6861e-01, Learning rate: 1.0000e-02
# Epoch 820, Training loss: -1.0122e+00, Test loss: 2.7111e-01, Learning rate: 1.0000e-02
# Epoch 830, Training loss: -1.0157e+00, Test loss: 2.5998e-01, Learning rate: 1.0000e-02
# Epoch 840, Training loss: -9.9946e-01, Test loss: 2.5872e-01, Learning rate: 1.0000e-02
# Epoch 850, Training loss: -9.9912e-01, Test loss: 2.6053e-01, Learning rate: 1.0000e-02
# Epoch 860, Training loss: -1.1041e+00, Test loss: 2.5505e-01, Learning rate: 1.0000e-02
# Epoch 870, Training loss: -1.0105e+00, Test loss: 2.5766e-01, Learning rate: 1.0000e-02
# Epoch 880, Training loss: -1.0338e+00, Test loss: 2.6877e-01, Learning rate: 1.0000e-02
# Epoch 890, Training loss: -9.9421e-01, Test loss: 2.6275e-01, Learning rate: 1.0000e-02
# Epoch 900, Training loss: -9.6826e-01, Test loss: 2.6060e-01, Learning rate: 1.0000e-02
# Epoch 910, Training loss: -8.8613e-01, Test loss: 2.5978e-01, Learning rate: 1.0000e-02
# Epoch 920, Training loss: -9.9690e-01, Test loss: 2.6227e-01, Learning rate: 1.0000e-02
# Epoch 930, Training loss: -1.0262e+00, Test loss: 2.7004e-01, Learning rate: 1.0000e-02
# Epoch 940, Training loss: -9.5454e-01, Test loss: 2.6441e-01, Learning rate: 1.0000e-02
# Epoch 950, Training loss: -9.4969e-01, Test loss: 2.6404e-01, Learning rate: 1.0000e-02
# Epoch 960, Training loss: -1.1371e+00, Test loss: 2.6558e-01, Learning rate: 1.0000e-02
# Epoch 970, Training loss: -9.9999e-01, Test loss: 2.6777e-01, Learning rate: 1.0000e-02
# Epoch 980, Training loss: -9.9470e-01, Test loss: 2.6563e-01, Learning rate: 1.0000e-02
# Epoch 990, Training loss: -1.0292e+00, Test loss: 2.6466e-01, Learning rate: 1.0000e-02
# Epoch 1000, Training loss: -1.0009e+00, Test loss: 2.6318e-01, Learning rate: 1.0000e-02
# Epoch 1100, Training loss: -1.0726e+00, Test loss: 2.7177e-01, Learning rate: 1.0000e-02
# Epoch 1200, Training loss: -1.0510e+00, Test loss: 2.6595e-01, Learning rate: 1.0000e-02
# Epoch 1300, Training loss: -1.0148e+00, Test loss: 2.6280e-01, Learning rate: 1.0000e-02
# Epoch 1400, Training loss: -1.0507e+00, Test loss: 2.6606e-01, Learning rate: 1.0000e-02
# Epoch 1500, Training loss: -8.8232e-01, Test loss: 2.6573e-01, Learning rate: 1.0000e-02
# Epoch 1600, Training loss: -1.0148e+00, Test loss: 2.5934e-01, Learning rate: 1.0000e-02
# Epoch 1700, Training loss: -9.1134e-01, Test loss: 2.6887e-01, Learning rate: 1.0000e-02
# Epoch 1800, Training loss: -1.0010e+00, Test loss: 2.5778e-01, Learning rate: 1.0000e-02
# Epoch 1900, Training loss: -1.0420e+00, Test loss: 2.6071e-01, Learning rate: 1.0000e-02
# Epoch 2000, Training loss: -8.7385e-01, Test loss: 2.6289e-01, Learning rate: 1.0000e-02
# Epoch 2100, Training loss: -1.0015e+00, Test loss: 2.6413e-01, Learning rate: 1.0000e-02
# Epoch 2200, Training loss: -9.9998e-01, Test loss: 2.5944e-01, Learning rate: 1.0000e-02
# Epoch 2300, Training loss: -9.9983e-01, Test loss: 2.8402e-01, Learning rate: 1.0000e-02
# Epoch 2400, Training loss: -1.0131e+00, Test loss: 2.7241e-01, Learning rate: 1.0000e-02
# Epoch 2500, Training loss: -9.9875e-01, Test loss: 2.7370e-01, Learning rate: 1.0000e-02
# Epoch 2600, Training loss: -9.7713e-01, Test loss: 2.8288e-01, Learning rate: 1.0000e-02
# Epoch 2700, Training loss: -1.0661e+00, Test loss: 2.8944e-01, Learning rate: 1.0000e-02
# Epoch 2800, Training loss: -1.0180e+00, Test loss: 2.6655e-01, Learning rate: 1.0000e-02
# Epoch 2900, Training loss: -1.0333e+00, Test loss: 2.6550e-01, Learning rate: 1.0000e-02
# Epoch 3000, Training loss: -9.9543e-01, Test loss: 2.7282e-01, Learning rate: 1.0000e-02
# Epoch 3100, Training loss: -9.9976e-01, Test loss: 2.7052e-01, Learning rate: 1.0000e-02
# Epoch 3200, Training loss: -9.0146e-01, Test loss: 2.7245e-01, Learning rate: 1.0000e-02
# Epoch 3300, Training loss: -1.0178e+00, Test loss: 2.6386e-01, Learning rate: 1.0000e-02
# Epoch 3400, Training loss: -1.0121e+00, Test loss: 2.5957e-01, Learning rate: 1.0000e-02
# Epoch 3500, Training loss: -1.0317e+00, Test loss: 2.6393e-01, Learning rate: 1.0000e-02
# Epoch 3600, Training loss: -1.0099e+00, Test loss: 2.8100e-01, Learning rate: 1.0000e-02
# Epoch 3700, Training loss: -1.0136e+00, Test loss: 2.9823e-01, Learning rate: 1.0000e-02
# Epoch 3800, Training loss: -1.1794e+00, Test loss: 2.6437e-01, Learning rate: 1.0000e-02
# Epoch 3900, Training loss: -1.0157e+00, Test loss: 2.6985e-01, Learning rate: 1.0000e-02
# Epoch 4000, Training loss: -9.9659e-01, Test loss: 2.8788e-01, Learning rate: 1.0000e-02
# Epoch 4100, Training loss: -1.0036e+00, Test loss: 2.7080e-01, Learning rate: 1.0000e-02
# Epoch 4200, Training loss: -1.0469e+00, Test loss: 2.7451e-01, Learning rate: 1.0000e-02
# Epoch 4300, Training loss: -1.0366e+00, Test loss: 2.5835e-01, Learning rate: 1.0000e-02
# Epoch 4400, Training loss: -1.0736e+00, Test loss: 2.6357e-01, Learning rate: 1.0000e-02
# Epoch 4500, Training loss: -1.0048e+00, Test loss: 2.6485e-01, Learning rate: 1.0000e-02
# Epoch 4600, Training loss: -1.0059e+00, Test loss: 2.7942e-01, Learning rate: 1.0000e-02
# Epoch 4700, Training loss: -1.0141e+00, Test loss: 2.6040e-01, Learning rate: 1.0000e-02
# Epoch 4800, Training loss: -1.0383e+00, Test loss: 2.5017e-01, Learning rate: 1.0000e-02
# Epoch 4900, Training loss: -1.0230e+00, Test loss: 2.4460e-01, Learning rate: 1.0000e-02
# Epoch 5000, Training loss: -9.9540e-01, Test loss: 2.5742e-01, Learning rate: 1.0000e-02
# Epoch 5100, Training loss: -9.8543e-01, Test loss: 2.8017e-01, Learning rate: 1.0000e-02
# Epoch 5200, Training loss: -8.8280e-01, Test loss: 2.6285e-01, Learning rate: 1.0000e-02
# Epoch 5300, Training loss: -9.9514e-01, Test loss: 2.5999e-01, Learning rate: 1.0000e-02
# Epoch 5400, Training loss: -1.0120e+00, Test loss: 2.4486e-01, Learning rate: 1.0000e-02
# Epoch 5500, Training loss: -9.9960e-01, Test loss: 2.6571e-01, Learning rate: 1.0000e-02
# Epoch 5600, Training loss: -1.0248e+00, Test loss: 2.4904e-01, Learning rate: 1.0000e-02
# Epoch 5700, Training loss: -1.0150e+00, Test loss: 2.4828e-01, Learning rate: 1.0000e-02
# Epoch 5800, Training loss: -1.0387e+00, Test loss: 2.6790e-01, Learning rate: 1.0000e-02
# Epoch 5900, Training loss: -9.6353e-01, Test loss: 2.8560e-01, Learning rate: 1.0000e-02
# Epoch 6000, Training loss: -9.9943e-01, Test loss: 3.2887e-01, Learning rate: 1.0000e-02
# Epoch 6100, Training loss: -1.1774e+00, Test loss: 2.5438e-01, Learning rate: 1.0000e-02
# Epoch 6200, Training loss: -1.0797e+00, Test loss: 2.6484e-01, Learning rate: 1.0000e-02
# Epoch 6300, Training loss: -9.8647e-01, Test loss: 2.5301e-01, Learning rate: 1.0000e-02
# Epoch 6400, Training loss: -1.0118e+00, Test loss: 2.7244e-01, Learning rate: 1.0000e-02
# Epoch 6500, Training loss: -9.8207e-01, Test loss: 2.4445e-01, Learning rate: 1.0000e-02
# Epoch 6600, Training loss: -1.0311e+00, Test loss: 2.5571e-01, Learning rate: 1.0000e-02
# Epoch 6700, Training loss: -1.0314e+00, Test loss: 2.3900e-01, Learning rate: 1.0000e-02
# Epoch 6800, Training loss: -1.0436e+00, Test loss: 2.3457e-01, Learning rate: 1.0000e-02
# Epoch 6900, Training loss: -1.0246e+00, Test loss: 2.3349e-01, Learning rate: 1.0000e-02
# Epoch 7000, Training loss: -1.0915e+00, Test loss: 2.3330e-01, Learning rate: 1.0000e-02
# Epoch 7100, Training loss: -1.1297e+00, Test loss: 2.3387e-01, Learning rate: 1.0000e-02
# Epoch 7200, Training loss: -1.1325e+00, Test loss: 2.2710e-01, Learning rate: 1.0000e-02
# Epoch 7300, Training loss: -1.0653e+00, Test loss: 2.2045e-01, Learning rate: 1.0000e-02
# Epoch 7400, Training loss: -1.0362e+00, Test loss: 2.3284e-01, Learning rate: 1.0000e-02
# Epoch 7500, Training loss: -1.0569e+00, Test loss: 2.3289e-01, Learning rate: 1.0000e-02
# Epoch 7600, Training loss: -1.0555e+00, Test loss: 2.2146e-01, Learning rate: 1.0000e-02
# Epoch 7700, Training loss: -1.0249e+00, Test loss: 2.2216e-01, Learning rate: 1.0000e-02
# Epoch 7800, Training loss: -1.0405e+00, Test loss: 2.2272e-01, Learning rate: 1.0000e-02
# Epoch 7900, Training loss: -9.9917e-01, Test loss: 2.0804e-01, Learning rate: 1.0000e-02
# Epoch 8000, Training loss: -9.9871e-01, Test loss: 2.1625e-01, Learning rate: 1.0000e-02
# Epoch 8100, Training loss: -9.9877e-01, Test loss: 2.3018e-01, Learning rate: 1.0000e-02
# Epoch 8200, Training loss: -1.1087e+00, Test loss: 1.8791e-01, Learning rate: 1.0000e-02
# Epoch 8300, Training loss: -1.1904e+00, Test loss: 1.8401e-01, Learning rate: 1.0000e-02
# Epoch 8400, Training loss: -1.0388e+00, Test loss: 1.7160e-01, Learning rate: 1.0000e-02
# Epoch 8500, Training loss: -1.0088e+00, Test loss: 2.2007e-01, Learning rate: 1.0000e-02
# Epoch 8600, Training loss: -1.0070e+00, Test loss: 1.7462e-01, Learning rate: 1.0000e-02
# Epoch 8700, Training loss: -1.1377e+00, Test loss: 1.8893e-01, Learning rate: 1.0000e-02
# Epoch 8800, Training loss: -1.0438e+00, Test loss: 1.9901e-01, Learning rate: 1.0000e-02
# Epoch 8900, Training loss: -1.0369e+00, Test loss: 1.8950e-01, Learning rate: 1.0000e-02
# Epoch 9000, Training loss: -1.0756e+00, Test loss: 2.0746e-01, Learning rate: 1.0000e-02
# Epoch 9100, Training loss: -1.0827e+00, Test loss: 1.7484e-01, Learning rate: 1.0000e-02
# Epoch 9200, Training loss: -1.0559e+00, Test loss: 1.8508e-01, Learning rate: 1.0000e-02
# Epoch 9300, Training loss: -1.0809e+00, Test loss: 1.6687e-01, Learning rate: 1.0000e-02
# Epoch 9400, Training loss: -1.0250e+00, Test loss: 2.0525e-01, Learning rate: 1.0000e-02
# Epoch 9500, Training loss: -1.1790e+00, Test loss: 1.5458e-01, Learning rate: 1.0000e-02
# Epoch 9600, Training loss: -1.0687e+00, Test loss: 1.5196e-01, Learning rate: 1.0000e-02
# Epoch 9700, Training loss: -1.0340e+00, Test loss: 1.6443e-01, Learning rate: 1.0000e-02
# Epoch 9800, Training loss: -1.0048e+00, Test loss: 1.6168e-01, Learning rate: 1.0000e-02
# Epoch 9900, Training loss: -9.9918e-01, Test loss: 1.6469e-01, Learning rate: 1.0000e-02
# Epoch 10000, Training loss: -1.0060e+00, Test loss: 1.7352e-01, Learning rate: 1.0000e-02
# Epoch 11000, Training loss: -1.0638e+00, Test loss: 1.6920e-01, Learning rate: 1.0000e-02
# Epoch 12000, Training loss: -1.0955e+00, Test loss: 1.6811e-01, Learning rate: 1.0000e-02
# Epoch 13000, Training loss: -1.1533e+00, Test loss: 1.3854e-01, Learning rate: 1.0000e-02
# Epoch 14000, Training loss: -1.0261e+00, Test loss: 1.8961e-01, Learning rate: 1.0000e-02

# %%
fig, axs = plt.subplots(1, 1, figsize=(8, 5))
axs.plot(test_loss, color='blue')
axs.set_ylim(5e-2, 1e0)
axs.set_xlabel('Iteration')
axs.set_ylabel('Relative Error')
axs.set_xscale('log')
axs.set_yscale('log')
axs.set_title('Monitoring Error')
# Out:
# Text(0.5, 1.0, 'Monitoring Error')

# %% [markdown]
# ### Test

# %%
# Load data
special_test = np.array(pd.read_csv('Dataset/special_test.csv').values)

fig, axs = plt.subplots(1, 3, figsize=(21, 5), dpi=300)


for i in range(len(special_test)):
    nodes_fullNN, u_fullNN = FEM_sol(trained_param, special_test[i])
    
    ritz_fullNN = solve_and_loss(forward_pass(special_test[i], trained_param), special_test[i])
    exact_ritz_val = Exact_Ritz(np.array(special_test[i][0]), np.array(special_test[i][1]), np.array(special_test[i][2]))

    ax = axs[i]
    ax.pcolormesh(nodes_fullNN[:,0].reshape(n_nodes//2+1,n_nodes//2+1), 
                    nodes_fullNN[:,1].reshape(n_nodes//2+1,n_nodes//2+1), 
                    u_fullNN.reshape(n_nodes//2+1,n_nodes//2+1), shading='gouraud')

    ax.set_xlabel('x')
    ax.set_ylabel('u')
    unique_x = np.unique(nodes_fullNN[:,0])
    unique_y = np.unique(nodes_fullNN[:,1])
    for xi in unique_x:
        ax.plot([xi] * len(unique_y), unique_y, color='r', linewidth=0.5)  # Líneas verticales
    for yi in unique_y:
        ax.plot(unique_x, [yi] * len(unique_x), color='r', linewidth=0.5)  # Líneas horizontales
    fig.colorbar(ax.collections[0], ax=ax, orientation='vertical')
    ax.legend([f'Exact Ritz = {exact_ritz_val:.4f}', 
               f'Ritz NN param = {ritz_fullNN:.4f}',]) 
    ax.set_title(rf'Comparison using $\sigma$ = ({special_test[i][0]:.4f}, {special_test[i][1]:.4f}, {special_test[i][2]:.4f})')
    
plt.tight_layout()
plt.show()

# %%
# Evaluate the NN in every validation data and then compare the loss with the exact Ritz value

# List to save the Ritz values
ritz_validation       = []
exact_ritz_validation = []
error_validation      = []
rel_error_validation  = []
rel_uniform_val       = []

# Evaluate the NN in every validation data
for i in range(len(test_data)):
    if i % 100 == 0:
        print(f"Evaluating test data {i}/{len(test_data)}")
    
    # Calculate the Ritz value
    ritz = solve_and_loss_scipy(forward_pass(test_data[i,:], trained_param), test_data[i,:].reshape(-1, 3)).item()
    ritz_validation.append(ritz)
    
    # Calculate the exact Ritz value
    exact_ritz = Exact_Ritz(test_data[i,:][0], test_data[i,:][1], test_data[i,:][2])
    exact_ritz_validation.append(exact_ritz)
    exact_ritz_bal = exact_ritz / ritz_dict_val[str(test_data[i,:])]

    # Calculate the error
    error = np.sqrt(abs((ritz - exact_ritz)/ritz_dict_val[str(test_data[i,:])]))
    error_validation.append(error)

    # Calculate the relative error
    rel_error = error / np.sqrt(abs(exact_ritz_bal))
    rel_error_validation.append(rel_error)
    
    # Calculate the relative error with the uniform grid
    rel_error_uni = np.sqrt(abs( (ritz_dict_val[str(test_data[i,:])] - exact_ritz) / exact_ritz ))
    rel_uniform_val.append(rel_error_uni)

# Evaluate the NN in every training data and then compare the loss with the exact Ritz value

# List to save the Ritz values
ritz_train          = []
exact_ritz_train    = []
error_train         = []
rel_error_train     = []
rel_uniform_train   = []

# Evaluate the NN in every training data
for i in range(len(train_data)):
    if i % 100 == 0:
        print(f"Evaluating train data {i}/{len(train_data)}")
    
    # Calculate the Ritz value
    ritz = solve_and_loss_scipy(forward_pass(train_data[i,:], trained_param), train_data[i,:].reshape(-1, 3)).item()
    ritz_train.append(ritz)
    
    # Calculate the exact Ritz value
    exact_ritz = Exact_Ritz(train_data[i,:][0], train_data[i,:][1], train_data[i,:][2])
    exact_ritz_train.append(exact_ritz)
    exact_ritz_bal = exact_ritz / ritz_dict_train[str(train_data[i,:])]

    # Calculate the error
    error = np.sqrt(abs((ritz - exact_ritz)/ritz_dict_train[str(train_data[i,:])]))
    error_train.append(error)

    # Calculate the relative error
    rel_error = error / np.sqrt(abs(exact_ritz_bal))
    rel_error_train.append(rel_error)

    # Calculate the relative error with the uniform grid
    rel_error_uni = np.sqrt(abs( (ritz_dict_train[str(train_data[i,:])] - exact_ritz) / exact_ritz ))
    rel_uniform_train.append(rel_error_uni)
# Out:
# Evaluating test data 0/600
# Evaluating test data 100/600
# Evaluating test data 200/600
# Evaluating test data 300/600
# Evaluating test data 400/600
# Evaluating test data 500/600
# Evaluating train data 0/1400
# Evaluating train data 100/1400
# Evaluating train data 200/1400
# Evaluating train data 300/1400
# Evaluating train data 400/1400
# Evaluating train data 500/1400
# Evaluating train data 600/1400
# Evaluating train data 700/1400
# Evaluating train data 800/1400
# Evaluating train data 900/1400
# Evaluating train data 1000/1400
# Evaluating train data 1100/1400
# Evaluating train data 1200/1400
# Evaluating train data 1300/1400

# %%
# Calcular estadísticas para el conjunto de entrenamiento
train_mean_abs_error = np.mean(error_train)
train_mean_rel_error = np.mean(rel_error_train)
train_std_abs_error = np.std(error_train)
train_std_rel_error = np.std(rel_error_train)
train_max_abs_error = np.max(error_train)
train_max_rel_error = np.max(rel_error_train)
train_uniform_mean_rel_error = np.mean(rel_uniform_train) 
train_uniform_max_rel_error = np.max(rel_uniform_train)

# Calcular estadísticas para el conjunto de validación
val_mean_abs_error = np.mean(error_validation)
val_mean_rel_error = np.mean(rel_error_validation)
val_std_abs_error = np.std(error_validation)
val_std_rel_error = np.std(rel_error_validation)
val_max_abs_error = np.max(error_validation)
val_max_rel_error = np.max(rel_error_validation)
val_uniform_mean_rel_error = np.mean(rel_uniform_val)
val_uniform_max_rel_error = np.max(rel_uniform_val)

# Crear un DataFrame con los resultados
data = {
    'Set': ['Train', 'Validation'],
    'Mean Absolute Error': [train_mean_abs_error, val_mean_abs_error],
    'Mean Relative Error': [train_mean_rel_error, val_mean_rel_error],
    'Std Absolute Error': [train_std_abs_error, val_std_abs_error],
    'Std Relative Error': [train_std_rel_error, val_std_rel_error],
    'Max Absolute Error': [train_max_abs_error, val_max_abs_error],
    'Max Relative Error': [train_max_rel_error, val_max_rel_error],
    'Uniform grid Mean Relative error': [train_uniform_mean_rel_error, val_uniform_mean_rel_error],
    'Uniform grid Max Relative error': [train_uniform_max_rel_error, val_uniform_max_rel_error]
}

df_errors = pd.DataFrame(data)
df_errors.to_csv('Error_result_N64.csv', index=False)
df_errors
# Out:
#           Set  Mean Absolute Error  Mean Relative Error  Std Absolute Error  \
# 0       Train             0.148234             0.140272            0.041693
# 1  Validation             0.146364             0.138289            0.040970
#
#    Std Relative Error  Max Absolute Error  Max Relative Error  \
# 0            0.037796            0.263353            0.234912
# 1            0.037084            0.233855            0.211021
#
#    Uniform grid Mean Relative error  Uniform grid Max Relative error
# 0                          0.284233                         0.457804
# 1                          0.287926                         0.454843
